# %%
import numpy as np
from src.reporting.file_util import read_as_df
from src.strategy.predict import arima
import matplotlib.pyplot as plt

total_df = read_as_df("total.csv")
total_df.head()

train_data, test_data = total_df[0:int(len(train_df)*0.8)], train_df[int(len(train_df)*0.8):]
plt.figure(figsize=(12,7))
plt.title('Microsoft Prices')
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.plot(train_data['price'], 'blue', label='Training Data')
plt.plot(test_data['price'], 'green', label='Testing Data')
plt.xticks(np.arange(0,500, 50), total_df['time_epoch_milli'][0:500:50])
plt.legend()
